# %%
import utils_show as utils
import numpy as np
from pattern.en import lemma
from collections import defaultdict

# %%
coordination_captions = utils.read_json_file('data/coordination.json')
len(coordination_captions)
# Out:
# close file...
# 800

# %% [markdown]
# # Coordination
# Dataset size: 800
#
# Demo example number: 5

# %%
n_demo = 5
selects = np.random.randint(0, len(coordination_captions), n_demo)

# %%
for i in selects:
    img = coordination_captions[i]
    img_id = img['image_id']
    utils.show_image(img_id)
    print(img_id)
    caption = img['caption_group'][0]
    print(caption['True1'])
    print(caption['True2'])
    print(caption['False1'])
    print(caption['False2'])
# Out:
# 2358186
# the woman wears black pants and has a drink
# the man wears shoes and stands behind a woman
# the woman wears black pants and wears shoes
# the man has a drink and stands behind a woman
# 2390719
# the man wears a white jacket and holds a blue tennis racquet
# the girl wears a black girl's jacket and holds a red tennis racquet
# the man wears a white jacket and holds a red tennis racquet
# the girl holds a blue tennis racquet and wears a black girl's jacket
# 2403345
# the catcher has a brown glove and wears a red helmet
# the batter holds a black bat and wears a blac helmet
# the catcher has a brown glove and holds a black bat
# the batter wears a red helmet and wears a blac helmet
# 2353639
# the woman talks on a phone and wears a beige burka
# the little girl sits next to a woman and sits on a rug
# the woman talks on a phone and sits next to a woman
# the little girl wears a beige burka and sits on a rug
# 2414861
# the man wears blue jeans and wears an orange t-shirt
# the man wears shorts and wears a buttoned down shirt
# the man wears blue jeans and wears shorts
# the man wears an orange t-shirt and wears a buttoned down shirt
