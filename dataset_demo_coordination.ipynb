# %%
import utils_show as utils
import numpy as np
from pattern.en import lemma
from collections import defaultdict

# %%
coordination_captions = utils.read_json_file('data/coordination_captions_gruen_strict.json')
len(coordination_captions)
# Out:
# close file...
# 654

# %% [markdown]
# # Coordination
# Dataset size: 650-> 654
#
# Demo example number: 5

# %%
n_demo = 5
selects = np.random.randint(0, len(coordination_captions), n_demo)

# %%
for i in selects:
    img = coordination_captions[i]
    img_id = img['image_id']
    utils.show_image(img_id)
    print(img_id)
    caption = img['caption_group'][0]
    print(caption['True1'])
    print(caption['True2'])
    print(caption['False1'])
    print(caption['False2'])
# Out:
# 2330005
# the man wears light blue jeans and wears a white shirt
# the man holds a blue and red flag and wears shorts
# the man wears light blue jeans and holds a blue and red flag
# the man wears a white shirt and wears shorts
# 2378650
# the girl holds a yellow tennis racket and wears a cute sandal
# the boy wears plaid shorts and wears a blue shirt
# the girl holds a yellow tennis racket and wears plaid shorts
# the boy wears a cute sandal and wears a blue shirt
# 2388076
# the girl wears a white shirt and wears a black skirt
# the woman holds a black and white racket and wears a blue and purple
# the girl wears a white shirt and holds a black and white racket
# the woman wears a black skirt and wears a blue and purple
# 2354046
# the man wears gray and grey pants and wears shoes
# the woman wears a black dress and wears a denim skirt
# the man wears gray and grey pants and wears a black dress
# the woman wears shoes and wears a denim skirt
# 2364569
# the man holds a bat and wears a blue shirt
# the man wears a black shirt and wears gray pants
# the man holds a bat and wears a black shirt
# the man wears a blue shirt and wears gray pants
