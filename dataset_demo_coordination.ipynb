# %%
import utils_show as utils
import numpy as np
from pattern.en import lemma
from collections import defaultdict

# %%
coordination_captions = utils.read_json_file('data/coordination_captions_gruen_strict.json')
len(coordination_captions)
# Out:
# close file...
# 573

# %% [markdown]
# # Coordination
# Dataset size: 584->
#
# Demo example number: 5

# %%
n_demo = 5
selects = np.random.randint(0, len(coordination_captions), n_demo)

# %%
for i in selects:
    img = coordination_captions[i]
    img_id = img['image_id']
    utils.show_image(img_id)
    print(img_id)
    caption = img['caption_group'][0]
    print(caption['True1'])
    print(caption['True2'])
    print(caption['False1'])
    print(caption['False2'])
# Out:
# 2409700
# the woman wears blue jeans and has a white headband
# the woman wears a tank and wears pants
# the woman wears blue jeans and wears a tank
# the woman has a white headband and wears pants
# 2343383
# the man sits in a grey chair and wears a black blood pressure cuff
# the woman wears a white lab coat and has a neck
# the man sits in a grey chair and wears a white lab coat
# the woman wears a black blood pressure cuff and has a neck
# 2386069
# the woman holds a plastic soda bottle and eats a sandwich
# the woman carries a brown purse and wears jeans
# the woman holds a plastic soda bottle and carries a brown purse
# the woman eats a sandwich and wears jeans
# 2391088
# the woman holds an orange spray bottle and wears a purple hoodie
# the boy wears a blue salon apron and sits in a blue barber chair
# the woman holds an orange spray bottle and wears a blue salon apron
# the boy wears a purple hoodie and sits in a blue barber chair
# 2345648
# the woman has a red kerchief and wears a red and yellow skirt
# the woman has a green shirt and stands under a tan umbrella
# the woman has a red kerchief and has a green shirt
# the woman wears a red and yellow skirt and stands under a tan umbrella
