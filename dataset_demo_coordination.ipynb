# %%
import utils_show as utils
import numpy as np
from pattern.en import lemma
from collections import defaultdict

# %%
coordination_captions = utils.read_json_file('data/coordination_captions_gruen_strict.json')
len(coordination_captions)
# Out:
# close file...
# 650

# %% [markdown]
# # Coordination
# Dataset size: 584-> 650
#
# Demo example number: 5

# %%
n_demo = 5
selects = np.random.randint(0, len(coordination_captions), n_demo)

# %%
for i in selects:
    img = coordination_captions[i]
    img_id = img['image_id']
    utils.show_image(img_id)
    print(img_id)
    caption = img['caption_group'][0]
    print(caption['True1'])
    print(caption['True2'])
    print(caption['False1'])
    print(caption['False2'])
# Out:
# 2334333
# the man wears jeans and wears a strap
# the man wears dark pants and wears a short sleeved shirt
# the man wears jeans and wears dark pants
# the man wears a strap and wears a short sleeved shirt
# 2362756
# the man wears a red shirt and wears long pants
# the man sits on a grey and white ramp and wears blue jeans
# the man wears a red shirt and sits on a grey and white ramp
# the man wears long pants and wears blue jeans
# 2384234
# the lady wears a red jacket and crosses a street
# the man wears a black sweater and stands by a red and orange bus
# the lady wears a red jacket and wears a black sweater
# the man crosses a street and stands by a red and orange bus
# 2351851
# the man sits on a green bench and drinks water
# the woman wears a pink sweater and wears a polka dot shirt
# the man sits on a green bench and wears a pink sweater
# the woman drinks water and wears a polka dot shirt
# 2396337
# the boy wears a red shirt and wears blue shorts
# the child wears a white t-shirt and wears an orange and yellow hat
# the boy wears a red shirt and wears a white t-shirt
# the child wears blue shorts and wears an orange and yellow hat
