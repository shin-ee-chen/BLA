# %%
import utils_show as utils
import numpy as np
from pattern.en import lemma
from collections import defaultdict

# %%
rc_captions = utils.read_json_file('data/relative_clause.json')
len(rc_captions)
# Out:
# close file...
# 789

# %% [markdown]
# # Relative Clause
# Dataset size: 789
#
# Demo example number: 5

# %%
n_demo = 5
selects = np.random.randint(0, len(rc_captions), n_demo)

# %%
for i in selects:
    img = rc_captions[i]
    img_id = img['image_id']
    utils.show_image(img_id)
    print(img_id)
    caption = img['caption_group'][0]
    print(caption['True1'])
    print(caption['True2'])
    print(caption['False1'])
    print(caption['False2'])
# Out:
# 2401528
# the man who wears blue jeans wears a t shirt
# the woman who wears a gray shirt wears a lei
# the man who wears blue jeans wears a gray shirt
# the woman who wears a t shirt wears a lei
# 2412465
# the man who wears a for safety helmet wears a white shirt
# the man who wears a blue shirt has folded arms
# the man who wears a for safety helmet wears a blue shirt
# the man who wears a white shirt has folded arms
# 2392551
# the boy who wears a white shirt wears navy shorts
# the man who plays tennis plays a blue tennis court
# the boy who wears a white shirt plays tennis
# the man who wears navy shorts plays a blue tennis court
# 2365398
# the man who has a black jacket sits on a bike
# the man who walks near a small car walks on a street
# the man who has a black jacket walks near a small car
# the man who sits on a bike walks on a street
# 2379995
# the man who wears jeans shorts wears a sleeveless shirt
# the man who wears a red shirt wears black shoes
# the man who wears jeans shorts wears a red shirt
# the man who wears a sleeveless shirt wears black shoes
