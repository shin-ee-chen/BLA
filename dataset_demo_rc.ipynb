# %%
import utils_show as utils
import numpy as np
from pattern.en import lemma
from collections import defaultdict
from nltk.corpus import wordnet as wn

# %%
rc_captions = utils.read_json_file('data/test_data/relative_clause_captions_non_person_object_gruen_strict.json')
len(rc_captions)
# Out:
# close file...
# 787

# %% [markdown]
# # Relative Clause
# Dataset size: 789 (old) -> 787 (new)
#
# Demo example number: 10

# %%
n_demo = 10
selects = np.random.randint(0, len(rc_captions), n_demo)

# %%
for i in selects:
    img = rc_captions[i]
    img_id = img['image_id']
    utils.show_image(img_id)
    print(img_id)
    caption = img['caption_group'][0]
    print(caption['True1'])
    print(caption['True2'])
    print(caption['False1'])
    print(caption['False2'])
    print()
# Out:
# 73
# the man who sits in a chair wears a yellow tie
# the man who wears a dark suit wears a striped shirt
# the man who sits in a chair wears a striped shirt
# the man who wears a dark suit wears a yellow tie
# 2350212
# the person who wears khaki pants sits on a light beige couch
# the person who wears a dark hat wears a white shirt
# the person who wears khaki pants wears a white shirt
# the person who wears a dark hat sits on a light beige couch
# 2370712
# the person who wears a white shirt sits at a tan table
# the person who eats a pizza wears an orange shirt
# the person who wears a white shirt wears an orange shirt
# the person who eats a pizza sits at a tan table
# 2385022
# the person who wears a multicolored skirt wears a blue shirt
# the person who wears black shorts wears a tshirt
# the person who wears a multicolored skirt wears a tshirt
# the person who wears black shorts wears a blue shirt
# 2377560
# the person who sits on steps wears a black jacket
# the person who wears blue jeans wears a shirt
# the person who sits on steps wears a shirt
# the person who wears blue jeans wears a black jacket
# 2373197
# the man who dresses in blue jeans dresses in a white t-shirt
# the man who wears a black shirt wears clothes
# the man who dresses in blue jeans wears clothes
# the man who wears a black shirt dresses in a white t-shirt
# 2363946
# the person who wears a backpack wears a red jacket
# the person who rides a horse wears a jacket
# the person who wears a backpack wears a jacket
# the person who rides a horse wears a red jacket
# 2398495
# the person who plays with a controller sits on a wooden chair
# the person who sits on a floor wears a pink blouse
# the person who plays with a controller wears a pink blouse
# the person who sits on a floor sits on a wooden chair
# 2374717
# the person who wears white dress carries a red luggage
# the person who carries a black suitcase wears a hat
# the person who wears white dress wears a hat
# the person who carries a black suitcase carries a red luggage
# 2399797
# the girl who wears a yellow hat wears a blue jean skirt
# the girl who wears a white shirt holds a kite
# the girl who wears a yellow hat holds a kite
# the girl who wears a white shirt wears a blue jean skirt
