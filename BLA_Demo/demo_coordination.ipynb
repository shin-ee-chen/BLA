# %%
import utils_show as utils
import numpy as np
from pattern.en import lemma
from collections import defaultdict

# %%
coordination_captions = utils.read_json_file('annotations/coordination_captions.json')
len(coordination_captions)
# Out:
# close file...
# 654

# %% [markdown]
# # Coordination
# Dataset size: 654
#
# Demo example number: 5

# %%
n_demo = 5
print(len(coordination_captions))
selects = np.random.randint(0, len(coordination_captions), n_demo)
# Out:
# 654

# %%
for i in selects:
    img = coordination_captions[i]
    img_id = img['image_id']
    utils.show_image(img_id)
    print(img_id)
    caption = img['caption_group'][0]
    print(caption['True1'])
    print(caption['True2'])
    print(caption['False1'])
    print(caption['False2'])
# Out:
# 2400493
# the woman wears a white with red shirt and has on a purple hat
# the child wears a blue hat and wears a colorful shirt
# the woman wears a white with red shirt and wears a blue hat
# the child has on a purple hat and wears a colorful shirt
# 2363063
# the boy wears black and gray shorts and rides a gray and white skateboard
# the kid wears yellow pants and rides a flipping skateboard
# the boy wears black and gray shorts and rides a flipping skateboard
# the kid rides a gray and white skateboard and wears yellow pants
# 2377665
# the batter wears a black helmet and wears a pinstriped uniform
# the catcher wears a face gear and wears a red hat
# the batter wears a black helmet and wears a face gear
# the catcher wears a pinstriped uniform and wears a red hat
# 2343378
# the man wears black shorts and wears a shirt
# the woman wears red and black shorts and wears a white top
# the man wears black shorts and wears a white top
# ...
